# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
pd.set_option('future.no_silent_downcasting', True)

# %% [markdown]
# # Reading the Data

# %%
data = pd.read_csv('cleaned_churn_data.csv')
data.head()
# Out:
#    customerID  Churn  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  0002-ORFBO      0  Female              0        1           1       9
# 1  0003-MKNFE      0    Male              0        0           0       9
# 2  0004-TLHLJ      1    Male              0        0           0       4
# 3  0011-IGKFF      1    Male              1        1           0      13
# 4  0013-EXCHZ      1  Female              1        1           0       3
#
#    PhoneService  MultipleLines InternetService  ...  TechSupport  StreamingTV  \
# 0             1              0             DSL  ...            1            1
# 1             1              1             DSL  ...            0            0
# 2             1              0     Fiber optic  ...            0            0
# 3             1              0     Fiber optic  ...            0            1
# 4             1              0     Fiber optic  ...            1            1
#
# ...

# %% [markdown]
# # Analysing the Churn column

# %% [markdown]
# ## Variable Statistics

# %%
data.Churn.describe()
# Out:
# count    7043.000000
# mean        0.265370
# std         0.441561
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: Churn, dtype: float64

# %% [markdown]
# We can see by the statistics that we have a slight imbalance on the values, with more examples of False values.

# %% [markdown]
# To make it easier to plot the distribution let's replace 1's and 0's for True and False

# %%
aux = data.copy()
aux['Churn'] = aux['Churn'].replace({1 : True, 0 : False})
aux['Churn'] = aux['Churn'].infer_objects(copy=False)

# %%
fig = px.histogram(aux, x = 'Churn')

fig.update_layout(yaxis_title = 'Count')

fig.update_xaxes(
    tickvals=['false', 'true'],
    ticktext=['False', 'True']  
)

fig.show()
